# %% [markdown]
# <a href="https://colab.research.google.com/github/jomariy241/assignment/blob/main/UnsupervisedLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/fish.csv')

# %%
df.head()
# Out:
#    Bream  242.0  23.2  25.4  30.0  38.4  13.4
# 0  Bream  290.0  24.0  26.3  31.2  40.0  13.8
# 1  Bream  340.0  23.9  26.5  31.1  39.8  15.1
# 2  Bream  363.0  26.3  29.0  33.5  38.0  13.3
# 3  Bream  430.0  26.5  29.0  34.0  36.6  15.1
# 4  Bream  450.0  26.8  29.7  34.7  39.2  14.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Bream   84 non-null     object
#  1   242.0   84 non-null     float64
#  2   23.2    84 non-null     float64
#  3   25.4    84 non-null     float64
#  4   30.0    84 non-null     float64
#  5   38.4    84 non-null     float64
#  6   13.4    84 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 4.7+ KB

# %%
df.describe()
# Out:
#              242.0       23.2       25.4       30.0       38.4       13.4
# count    84.000000  84.000000  84.000000  84.000000  84.000000  84.000000
# mean    434.017857  27.388095  29.607143  33.157143  27.953571  12.859524
# std     382.648669  11.348058  12.249630  13.272086  10.351142   2.129377
# min       0.000000   9.300000   9.800000  10.800000  14.500000   8.700000
# 25%     120.000000  19.325000  20.950000  23.550000  16.875000  10.875000
# 50%     390.000000  28.450000  30.850000  35.050000  26.900000  13.700000
# 75%     657.500000  32.725000  36.000000  40.675000  39.225000  14.700000
# max    1650.000000  59.000000  63.400000  68.000000  44.500000  16.100000

# %%
df.isna().sum()
# Out:
# Bream    0
# 242.0    0
# 23.2     0
# 25.4     0
# 30.0     0
# 38.4     0
# 13.4     0
# dtype: int64

# %%
df.nunique()
# Out:
# Bream     4
# 242.0    65
# 23.2     71
# 25.4     61
# 30.0     71
# 38.4     68
# 13.4     45
# dtype: int64

# %%
col_name=['Type','weight','l1','l2','l3','height','width']

# %%
df.columns=col_name

# %%
df.head()
# Out:
#     Type  weight    l1    l2    l3  height  width
# 0  Bream   290.0  24.0  26.3  31.2    40.0   13.8
# 1  Bream   340.0  23.9  26.5  31.1    39.8   15.1
# 2  Bream   363.0  26.3  29.0  33.5    38.0   13.3
# 3  Bream   430.0  26.5  29.0  34.0    36.6   15.1
# 4  Bream   450.0  26.8  29.7  34.7    39.2   14.2

# %%
df.columns
# Out:
# Index(['Type', 'weight', 'l1', 'l2', 'l3', 'height', 'width'], dtype='object')

# %%
#creating model
x=df[['Type', 'weight', 'l1', 'l2', 'l3', 'height', 'width']]
x.head()
# Out:
#     Type  weight    l1    l2    l3  height  width
# 0  Bream   290.0  24.0  26.3  31.2    40.0   13.8
# 1  Bream   340.0  23.9  26.5  31.1    39.8   15.1
# 2  Bream   363.0  26.3  29.0  33.5    38.0   13.3
# 3  Bream   430.0  26.5  29.0  34.0    36.6   15.1
# 4  Bream   450.0  26.8  29.7  34.7    39.2   14.2

# %%
#label encording
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
x['Type'] = le.fit_transform(x['Type'])
x.head()
# Out:
#    Type  weight    l1    l2    l3  height  width
# 0     0   290.0  24.0  26.3  31.2    40.0   13.8
# 1     0   340.0  23.9  26.5  31.1    39.8   15.1
# 2     0   363.0  26.3  29.0  33.5    38.0   13.3
# 3     0   430.0  26.5  29.0  34.0    36.6   15.1
# 4     0   450.0  26.8  29.7  34.7    39.2   14.2

# %%
#kmean cluster
inertia = []
k_range = range(1, 11)

# %%
for k in k_range:
  kmeans = KMeans(n_clusters=k, random_state=42)
  kmeans.fit(features)
  inertia.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
plt.plot(range(1,11),inertia)
plt.xlabel('weight')
plt.ylabel('l1')
plt.title('Clusters')
plt.grid()

# %%
km=KMeans(n_clusters=4,n_init=10)
km.fit(x)
# Out:
# KMeans(n_clusters=4, n_init=10)

# %%
cluster_labele=km.predict(x)

# %%
pd.Series(cluster_labele)
# Out:
# 0     2
# 1     2
# 2     2
# 3     2
# 4     2
#      ..
# 79    1
# 80    3
# 81    3
# 82    3
# 83    3
# Length: 84, dtype: int32

# %%
plt.scatter(x['weight'],x['l1'],c=cluster_labele)
plt.xlabel('weight')
plt.ylabel('l1')
plt.title('Clusters')

plt.grid()

# %%
df['cluster_labele']=cluster_labele

# %%
cluster_indices=[np.where(cluster_labele==i)[0] ]

# %%
colour=['r','g','b','c','m']

for i in range(max(cluster_labele+1)):
  cluster_data = x[cluster_labele==i]
  plt.scatter(cluster_data['weight'],cluster_data['l1'],c=colour[i])
  plt.xlabel('weight')
  plt.ylabel('l1')
  plt.title('Clusters')
plt.grid()

# %%
#prediction
def predict_cluster(genre,age,annual_income,spending_score):
  new_data=[[weight,l1,l2,l3,height,width]]
  cluster=km.predict(new_data)
  return cluster[0]

# %%
#agglomerative hc
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import fcluster

# %%
mergings=linkage(x,method='ward')

# %%
plt.figure(figsize=(15,10))
dendrogram(mergings)
plt.axhline(350,c='green',linestyle='--')
plt.show()

# %%
cluster_labele=fcluster(mergings,350,criterion='distance')

# %%
colour=['r','g','b','c','m']

for i in range(max(cluster_labele+1)):
  cluster_data = x[cluster_labele==i]
  plt.scatter(cluster_data['weight'],cluster_data['l1'],c=colour[i]) # Changed cluster_dfo to cluster_data
  plt.xlabel('weight')
  plt.ylabel('l1')
  plt.title('Clusters')
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-70-2476cc0f3d86> in <cell line: 3>()
#       3 for i in range(max(cluster_labele+1)):
#       4   cluster_data = x[cluster_labele==i]
# ----> 5   plt.scatter(cluster_data['weight'],cluster_data['l1'],c=colour[i]) # Changed cluster_dfo to cluster_data
#       6   plt.xlabel('weight')
#       7   plt.ylabel('l1')
#
# IndexError: list index out of range

# %%
from sklearn.metrics import silhouette_score
sil_avg=silhouette_score(x,cluster_labele)
print(f'silhouette average:{sil_avg}')
# Out:
# silhouette average:0.6440351368815718
